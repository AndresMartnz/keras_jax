# %% [markdown]
# # Posibles problemas a resolver

# %% [markdown]
# 2. **Stellar Structure: Lane-Emden Equation**
#
#    Lane-Emden Equation:
#
#    $$\frac{1}{\xi^2}\frac{d}{d\xi}\left(\xi^2\frac{d\theta}{d\xi}\right) + \theta^n = 0,$$

# %% [markdown]
# # Lane-Emden equation

# %% [markdown]
# In astrophysics, the Lane–Emden equation is a dimensionless form of Poisson's equation for the gravitational potential of a Newtonian self-gravitating, spherically symmetric, polytropic fluid. It is named after astrophysicists Jonathan Homer Lane and Robert Emden.[1] The equation reads
#
# $
# \frac{1}{\xi^{2}}\frac{d}{d\xi}\left(\xi^{2}\frac{d\theta}{d\xi}\right) + \theta^n = 0,
# $
#
# where $\xi$ is a dimensionless radius and $\theta$ is related to the density, and thus the pressure, by $\rho = \rho_c \theta^n$ for central density $\rho_c$. The index $n$ is the polytropic index that appears in the polytropic equation of state,
#
# $
# P = K\rho^{1+\frac{1}{n}},
# $
#
# where $P$ and $\rho$ are the pressure and density, respectively, and $K$ is a constant of proportionality. The standard boundary conditions are $\theta(0) = 1$ and $\theta'(0) = 0$. Solutions thus describe the run of pressure and density with radius and are known as polytropes of index $n$. If an isothermal fluid (polytropic index tends to infinity) is used instead of a polytropic fluid, one obtains the Emden–Chandrasekhar equation.

# %% [markdown]
# # Exact solutions

# %% [markdown]
# For a given value of the polytropic index $n$, denote the solution to the Lane–Emden equation as $\theta_n(\xi)$. In general, the Lane–Emden equation must be solved numerically to find $\theta_n$. There are exact, analytic solutions for certain values of $n$, in particular: $n = 0,1,5$.  For $n$ between 0 and 5, the solutions are continuous and finite in extent, with the radius of the star given by $R = \alpha \xi_1 $, where $\theta_n(\xi_1) = 0$.
#
# For a given solution $\theta_n$, the density profile is given by
# $ \rho = \rho_c \theta_n^n .$
#
# The total mass $M$ of the model star can be found by integrating the density over radius, from 0 to $\xi_1$.
#
# The pressure can be found using the polytropic equation of state, $P = K \rho^{1+\frac{1}{n}} $, i.e.
# $ P = K \rho_c^{1+\frac{1}{n}} \theta_n^{n+1}$
#
# Finally, if the gas is [[ideal gas law|ideal]], the equation of state is $P = k_B\rho T/\mu$, where $k_B$ is the [[Boltzmann constant]] and $\mu$ the mean molecular weight. The temperature profile is then given by
# $ T = \frac{K\mu}{k_B} \rho_c^{1/n} \theta_n $
#
# In spherically symmetric cases, the Lane–Emden equation is integrable for only three values of the polytropic index $n$.
#
#
# **For $n$ = 0**
#
# If $n = 0$, the equation becomes
# $ \frac{1}{\xi^2} \frac{d}{d\xi} \left( \xi^2 \frac{d\theta}{d\xi} \right) + 1 = 0 $
#
# Re-arranging and integrating once gives
# $ \xi^2\frac{d\theta}{d\xi} = C_1-\frac{1}{3}\xi^3 $
#
# Dividing both sides by $\xi^2$ and integrating again gives
# $ \theta(\xi)=C_0-\frac{C_1}{\xi}-\frac{1}{6}\xi^2 $
#
# The boundary conditions $\theta(0)=1$ and $\theta'(0)=0$ imply that the constants of integration are $C_0 = 1$ and $C_1 = 0$. Therefore,
# $ \theta(\xi) = 1 - \frac{1}{6}\xi^2$
#
# **For $n$ = 1**
#
# When $n = 1$, the equation can be expanded in the form
# $ \frac{d^2\theta}{d\xi^2}+\frac{2}{\xi}\frac{d\theta}{d\xi} + \theta = 0 $
#
# One assumes a power series solution:
# $ \theta(\xi) = \sum_{n=0}^\infty a_n \xi^n $
#
# This leads to a recursive relationship for the expansion coefficients:
# $ a_{n+2} = -\frac{a_n}{(n+3)(n+2)} $
#
# This relation can be solved leading to the general solution:
# $ \theta(\xi)=a_0 \frac{\sin\xi}{\xi} + a_1 \frac{\cos\xi}{\xi} $
#
# The boundary condition for a physical polytrope demands that $ \theta(\xi) \rightarrow 1$ as $ \xi \rightarrow 0 $.
# This requires that $ a_0 = 1, a_1 = 0 $, thus leading to the solution:
# $ \theta(\xi)=\frac{\sin\xi}{\xi} $
#
# **For $n$ = 5**
#
# We start from with the Lane–Emden equation:
# $ \frac1{\xi^2} {\frac{d}{d\xi}} \left(\xi^2\frac{d\theta}{d\xi}\right) + \theta^5 = 0 $
#
# Rewriting for $ \frac{d\theta}{d\xi} $ produces:
# $ \frac{d\theta} {d\xi} = \frac1 2 \left(1+\frac{\xi^2}{3}\right)^{3/2} \frac{2\xi} 3 = \frac {\xi^3}{3 \left[ 1+\frac {\xi^2} 3 \right]^{3/2}}
#  $
#
# Differentiating with respect to $ \xi $ leads to:
# $ \theta^5 =\frac{\xi^2}{\left[1+\frac{\xi^2}{3}\right]^{3/2}} + \frac{3\xi^2}{9\left[1+\frac{\xi^2}3\right]^{5/2}} = \frac 9 {9\left[1+\frac{\xi^2}3\right]^{5/2}}
# $
#
# Reduced, we come by:
# $ \theta^5 = \frac 1 { \left[ 1+\frac{\xi^2}3 \right]^{5/2}}$
#
# Therefore, the Lane–Emden equation has the solution
# $ \theta(\xi) = \frac 1 {\sqrt{1+\xi^2/3}} $
# when $n = 5$.
#
# This solution is finite in mass but infinite in radial extent, and therefore the complete polytrope does not represent a physical solution. Chandrasekhar believed for a long time that finding other solutions for $n=5$ "is complicated and involves elliptic integrals".
#
# **Srivastava's solution**
#
# In 1962, Sambhunath Srivastava found an explicit solution when $n=5$. His solution is given by
# $ \theta = \frac{\sin(\ln \sqrt \xi)}{\sqrt\xi \left[3-2 \sin^2 (\ln \sqrt\xi)\right]},$
# and from this solution, a family of solutions $ \theta(\xi)\rightarrow \sqrt A\, \theta(A\xi)$ can be obtained using homology transformation. Since this solution does not satisfy the conditions at the origin (in fact, it is oscillatory with amplitudes growing indefinitely as the origin is approached), this solution can be used in composite stellar models.

# %% [markdown]
# # Important libraries

# %%
#import tensorflow as tf
from keras.layers import Dense,Input
from keras.optimizers import Adam, RMSprop
from keras.models import load_model, save_model
from keras.saving import register_keras_serializable
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Circle
import cmath
import math
from tensorflow import keras
import tensorflow as tf
import time
import jax
import jax.numpy as jnp
from jax import lax
# from keras import optimizers

# %%
import tensorflow
print("Versión de TensorFlow:", tensorflow.__version__)
# Out:
# Versión de TensorFlow: 2.16.1

# %% [markdown]
# # Auxiliary functions

# %%
def plot_history_by_key(keys):
  import matplotlib.pyplot as plt
  for key in keys:
    plt.plot(history.history[key],marker='o',markersize=0.0, linewidth=1.0,label=key)
  plt.xlabel('epoch')
  plt.legend()
  plt.show()
  return history.history[key]

# %% [markdown]
# # Define the dimension of the problem

# %%
#n defines the politropic index of the system
n=0

# %% [markdown]
# # Definition of the PINN Lane-Emden equation

# %%
class ODE_2nd(keras.Model):

    def set_ODE_param(self,z0,r0,r0_grad,n, epsilon):
        '''
        Set parameters and initial conditions for the ODE
        '''
        #self.z0=z0
        self.z0=jnp.array(z0)
        #self.z0 = jnp.full((1, 1), float(z0[0]), dtype=jnp.float32)
        self.r0_true=r0
        self.r0_true_grad=r0_grad
        self.n=n
        self.epsilon=epsilon
    
    def compute_loss_and_updates(
        self,
        trainable_variables,
        non_trainable_variables,
        z,
        y,
        training=False,
    ):
        y_pred, non_trainable_variables = self.stateless_call(
            trainable_variables,
            non_trainable_variables,
            z,
            training=training,
        )
        y_z_pred=lax.grad(y_pred,z)
        y_z2_pred=lax.grad(y_z_pred,z)
        loss = self.compute_loss(z, y, y_pred)
        return loss, (y_pred, non_trainable_variables)

    def train_step(self, state, data):
        (
            trainable_variables,
            non_trainable_variables,
            optimizer_variables,
            metrics_variables,
        ) = state
        z, y = data

        # Get the gradient function.
        grad_fn = jax.value_and_grad(self.compute_loss_and_updates, has_aux=True)

        # Compute the gradients.
        (loss, (y_pred, non_trainable_variables)), grads = grad_fn(
            trainable_variables,
            non_trainable_variables,
            z,
            y,
            training=True,
        )

        # Update trainable variables and optimizer variables.
        (
            trainable_variables,
            optimizer_variables,
        ) = self.optimizer.stateless_apply(
            optimizer_variables, grads, trainable_variables
        )

        # Update metrics.
        new_metrics_vars = []
        logs = {}
        for metric in self.metrics:
            this_metric_vars = metrics_variables[
                len(new_metrics_vars) : len(new_metrics_vars) + len(metric.variables)
            ]
            if metric.name == "loss":
                this_metric_vars = metric.stateless_update_state(this_metric_vars, loss)
            else:
                this_metric_vars = metric.stateless_update_state(
                    this_metric_vars, y, y_pred
                )
            logs[metric.name] = metric.stateless_result(this_metric_vars)
            new_metrics_vars += this_metric_vars

        # Return metric logs and updated state variables.
        state = (
            trainable_variables,
            non_trainable_variables,
            optimizer_variables,
            new_metrics_vars,
        )
        return logs, state

# %%
# Initial conditions NN
#Divergence problems in z0=0 so we define an epsilon
epsilon=0.05

#We set the inicial conditions
r0=1
r0_grad=0


# We generate the values of z within the domain.
N_train = 10

z0 = 0+epsilon
zmax = 5
z_train=np.linspace(z0,zmax,N_train)
z_train=np.reshape(z_train,(N_train,1))

# Input and output neurons (from the data)
input_neurons  = 1
output_neurons = 1

# Hiperparameters
batch_size = 1
epochs = 4000

# Define the model
initializer = keras.initializers.GlorotUniform(seed=5)
activation='tanh'
input=Input(shape=(input_neurons,))
x=Dense(100, activation=activation,kernel_initializer=initializer)(input)
#x=Dense(100, activation=activation,kernel_initializer=initializer)(x)
#x=Dense(100, activation=activation,kernel_initializer=initializer)(x)
output = Dense(output_neurons,kernel_initializer=initializer,activation=None)(x)

# Build the model
model=ODE_2nd(input,output)

# Set ODE parameters and initial conditions
model.set_ODE_param(z0=[z0],r0=r0,r0_grad=r0_grad, n=n, epsilon=epsilon) #(dx_dz0=dx_dz0,A=A)

#Define the metrics, optimizer and loss
loss= keras.losses.MeanSquaredError()
metrics=keras.metrics.MeanSquaredError()
optimizer= Adam(learning_rate=0.00005) #normal 0.0001

model.compile(loss=loss,
          optimizer=optimizer,
          metrics=[metrics],
          run_eagerly=False)
model.summary()




print(z_train.shape)
y_train=np.zeros((z_train.shape[0],1))
print(y_train.shape)
# Out:
# Model: "ode_2nd_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 1)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 100)            │           200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 301 (1.18 KB)
#  Trainable params: 301 (1.18 KB)
#  Non-trainable params: 0 (0.00 B)
# (10, 1)
# (10, 1)

# %% [markdown]
# # Run the model

# %%
print(model.fit)
history=model.fit(z_train, y_train, batch_size=1, epochs=epochs,verbose=1) #,shuffle=False)
# Out:
# <bound method JAXTrainer.fit of <ODE_2nd name=ode_2nd_2, built=True>>
# Epoch 1/4000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 2
#       1 print(model.fit)
# ----> 2 history=model.fit(z_train, y_train, batch_size=1, epochs=epochs,verbose=1) #,shuffle=False)
#
# File c:\Users\usuario\Desktop\doctorado\codigos\keras_jax\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
#     [... skipping hidden 11 frame]
#
# Cell In[14], line 47, in ODE_2nd.train_step(self, state, data)
#      44 grad_fn = jax.value_and_grad(self.compute_loss_and_updates, has_aux=True)
#      46 # Compute the gradients.
# ---> 47 (loss, (y_pred, non_trainable_variables)), grads = grad_fn(
#      48     trainable_variables,
#      49     non_trainable_variables,
#      50     z,
#      51     y,
#      52     training=True,
#      53 )
#      55 # Update trainable variables and optimizer variables.
#      56 (
#      57     trainable_variables,
#      58     optimizer_variables,
#      59 ) = self.optimizer.stateless_apply(
#      60     optimizer_variables, grads, trainable_variables
#      61 )
#
#     [... skipping hidden 8 frame]
#
# Cell In[14], line 29, in ODE_2nd.compute_loss_and_updates(self, trainable_variables, non_trainable_variables, z, y, training)
#      15 def compute_loss_and_updates(
#      16     self,
#      17     trainable_variables,
#    (...)
#      21     training=False,
#      22 ):
#      23     y_pred, non_trainable_variables = self.stateless_call(
#      24         trainable_variables,
#      25         non_trainable_variables,
#      26         z,
#      27         training=training,
#      28     )
# ---> 29     y_z_pred=lax.grad(y_pred,z)
#      30     y_z2_pred=lax.grad(y_z_pred,z)
#      31     loss = self.compute_loss(z, y, y_pred)
#
# File c:\Users\usuario\Desktop\doctorado\codigos\keras_jax\.venv\Lib\site-packages\jax\_src\deprecations.py:54, in deprecation_getattr.<locals>.getattr(name)
#      52   warnings.warn(message, DeprecationWarning, stacklevel=2)
#      53   return fn
# ---> 54 raise AttributeError(f"module {module!r} has no attribute {name!r}")
#
# AttributeError: module 'jax.lax' has no attribute 'grad'

# %% [markdown]
# # Save files

# %%
ruta_archivo_save = 'modelos_Lane-Emden/n=-2z=2n=5 chincheta.keras'

save_model(model, ruta_archivo_save)

# %%
ruta_archivo_load = 'modelos_Lane-Emden/n=0z=10.keras'


model=load_model(ruta_archivo_load)

# %% [markdown]
# # Plot loss vs (last) epochs

# %%
#* Summarize history for loss
plt.plot(np.log10(history.history['loss']),marker='o',markersize=0.0, linewidth=1)
plt.xlabel('época',fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)


plt.legend(['función coste'], loc='upper left',fontsize=14)
plt.show()

# %%
#We get the prediction of the PINN

z_red=z_train
xy_pred=model.predict(z_red)
# Out:
# 7/7 [==============================] - 0s 2ms/step

# %% [markdown]
# # Runge Kutta

# %% [markdown]
# ## RK definitions

# %%
#* Evolution functions for each analitical solution
def f_x(t, x, n, epsilon2):
    if (n==0):
      return -t/3
    if (n==1):
      return ((t*np.cos(t)-np.sin(t))/(t**2+epsilon2))
    if (n==5):
      return(-np.sqrt(3)*t/(3+t**2)**(3/2))


#* Fourth-order Runge-Kutta method
def runge_kutta_4th_order(t, x, h, n, epsilon2):

    k1_x = h * f_x(t, x, n, epsilon2)

    k2_x = h * f_x(t + 0.5 * h, x + 0.5 * k1_x, n, epsilon2)

    k3_x = h * f_x(t + 0.5 * h, x + 0.5 * k2_x, n, epsilon2)

    k4_x = h * f_x(t + h, x + k3_x, n, epsilon2)

    new_x = x + (1/6) * (k1_x + 2 * k2_x + 2 * k3_x + k4_x)

    return new_x

# %% [markdown]
# ## Run RK

# %%
#* Initial conditions for the Runge-Kutta
epsilon2=0.001
t0=0
tfin=10
h=0.001
pasos=int((tfin-t0)/h)
x0_rk=1
t0_rk=t0

x_tot=[]
t_tot=[]

x_tot.append(x0_rk)
t_tot.append(t0_rk)


x_rk=x0_rk;
for i in range(pasos):
    x_rk= runge_kutta_4th_order(t0, x_rk, h, n, epsilon2)
    x_tot.append(x_rk)
    t0 += h
    t_tot.append(t0)
print(x_tot)
# Out:
# [1, 0.9999999999167292, 0.9999999986702395, 0.9999999932902933, 0.9999999788916538, 0.9999999487690098, 0.9999998945244466, 0.9999998062224881, 0.999999672566902, 0.9999994810929904, 0.999999218368971, 0.9999988702002772, 0.999998421831106, 0.9999978581382577, 0.999997163813174, 0.999996323529009, 0.9999953220905013, 0.9999941445653044, 0.9999927763962269, 0.9999912034945181, 0.9999894123148906, 0.9999873899133913, 0.9999851239895383, 0.999982602914326, 0.9999798157457955, 0.9999767522338838, 0.9999734028162136, 0.9999697586064012, 0.9999658113763323, 0.9999615535337173, 0.9999569780960893, 0.9999520786622562, 0.9999468493820737, 0.9999412849252692, 0.9999353804499218, 0.9999291315710876, 0.9999225343299644, 0.9999155851638963, 0.9999082808774513, 0.9999006186147337, 0.9998925958330476, 0.9998842102779789, 0.9998754599599301, 0.999866343132113, 0.999856858269984, 0.9998470040520867, 0.9998367793422547, 0.9998261831731216, 0.9998152147308725, 0.9998038733411744, 0.9997921584562136, 0.9997800696427763, 0.9997676065712999, 0.9997547690058317, 0.9997415567948298, 0.9997279698627441, 0.9997140082023199, 0.9996996718675674, 0.9996849609673457, 0.9996698756595127, 0.9996544161455935, 0.9996385826659262, 0.9996223754952456, 0.9996057949386666, 0.9995888413280356, 0.9995715150186162, 0.9995538163860831, 0.9995357458237953, 0.9995173037403261, 0.9994984905572258, 0.999479306706999, 0.999459752631275, 0.9994398287791559, 0.9994195356057272, 0.9993988735707138, 0.9993778431372716, 0.9993564447709009, 0.99933467893847, 0.9993125461073408, 0.9992900467445865, 0.9992671813162924, 0.9992439502869328, 0.9992203541188173, 0.9991963932715999, 0.9991720682018453, 0.9991473793626465, 0.9991223272032895, 0.9990969121689612, 0.9990711347004954, 0.9990449952341537, 0.9990184942014391, 0.9989916320289368, 0.9989644091381824, 0.9989368259455526, 0.9989088828621775, 0.998880580293872, 0.998851918641084, 0.998822898298859, 0.9987935196568173, 0.9987637830991452, 0.9987336890045957, 0.9987032377465009, 0.9986724296927924, 0.9986412652060292, 0.9986097446434341, 0.9985778683569349, 0.9985456366932116, 0.9985130499937492, 0.9984801085948937, 0.9984468128279117, 0.9984131630190545, 0.9983791594896233, 0.998344802556038, 0.9983100925299071, 0.9982750297180996, 0.9982396144228181, 0.998203846941673, 0.9981677275677573, 0.9981312565897221, 0.9980944342918526, 0.9980572609541437, 0.9980197368523763, 0.9979818622581932, 0.9979436374391741, 0.9979050626589118, 0.9978661381770858, 0.9978268642495374, 0.9977872411283424, 0.9977472690618844, 0.9977069482949265, 0.9976662790686823, 0.9976252616208865, 0.9975838961858637, 0.9975421829945973, 0.9975001222747962, 0.9974577142509615, 0.9974149591444517, 0.9973718571735467, 0.9973284085535113, 0.9972846134966573, 0.997240472212404, 0.9971959849073384, 0.9971511517852744, 0.99710597304731, 0.9970604488918844, 0.9970145795148334, 0.9969683651094441, 0.9969218058665082, 0.9968749019743748, 0.9968276536190013, 0.9967800609840043, 0.996732124250709, 0.9966838435981974, 0.9966352192033556, 0.9965862512409207, 0.9965369398835258, 0.9964872853017448, 0.9964372876641362, 0.9963869471372856, 0.9963362638858477, 0.9962852380725872, 0.9962338698584188, 0.9961821594024467, 0.9961301068620028, 0.9960777123926845, 0.9960249761483916, 0.995971898281362, 0.9959184789422074, 0.9958647182799475, 0.9958106164420439, 0.9957561735744336, 0.9957013898215604, 0.9956462653264078, 0.995590800230529, 0.9955349946740779, 0.9954788487958385, 0.9954223627332539, 0.9953655366224552, 0.9953083705982889, 0.9952508647943443, 0.9951930193429804, 0.9951348343753517, 0.9950763100214338, 0.9950174464100489, 0.9949582436688895, 0.9948987019245432, 0.9948388213025156, 0.9947786019272534, 0.9947180439221672, 0.9946571474096533, 0.9945959125111149, 0.9945343393469841, 0.9944724280367417, 0.9944101786989381, 0.9943475914512127, 0.9942846664103133, 0.9942214036921156, 0.9941578034116414, 0.9940938656830769, 0.9940295906197905, 0.9939649783343505, 0.9939000289385422, ...

# %% [markdown]
# # Plot the results

# %%
fig, ax = plt.subplots(dpi=150)
#* RK
ax.plot(t_tot, x_tot, linestyle='-', linewidth=1,color='b', label='Solución analítica')

#*chinchetas
ax.plot(aux2, aux, marker='o', markersize=4, linewidth=0,color='b', label='Chinchetas')

#*PINN
ax.plot(z_red, xy_pred, color="red",marker='o',markersize=1, linestyle='solid', linewidth=0, label=r"$\theta(\xi)$ PINN")
#ax.plot(z_red/7, 150*xy_pred**3, color="red",marker='o',markersize=5.0, linestyle='solid', linewidth=0.0, label=r"$\rho(r/R)$ PINN")

ax.set_title ("n=1", fontsize=14)
ax.set_xlabel(r'$\xi$', fontsize=16)
ax.set_ylabel(r'$\theta$', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.yscale("log", base=10)

#ax.set_xlabel(r'$r/R$')
#ax.set_ylabel(r'$\rho (g/cm^3)$')




plt.grid(True)
#plt.xlim(0,1)
#plt.ylim(0,1.1)
plt.legend(loc='upper right', bbox_to_anchor=(1.0, 1.2), fontsize=10)
plt.savefig(f'figuras Lane-Emden/n=1/Lane-Emden_chinchetas={N_intervalos}_n={n}_N={N_train_max}_z={zmax}.png')
plt.show()
